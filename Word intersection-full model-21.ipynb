# %%
import pathlib
import pandas as pd
import numpy as np

# %%
SUBMISSION_N = 21

# %%
DATA_DIR = pathlib.Path("data")

# %%
# %%time

train, test = [
    pd.read_csv(DATA_DIR.joinpath(filename), index_col="pair_id")
    for filename in (
        "train.csv",
        "test.csv",
    ) 
]
# Out:
# CPU times: user 402 ms, sys: 93.2 ms, total: 495 ms
# Wall time: 494 ms

# %%
# %%time

for dataset in (train, test):
    for column in ("name_1", 'name_2'):
        dataset[column] = dataset[column].str.lower()
# Out:
# CPU times: user 424 ms, sys: 63.8 ms, total: 488 ms
# Wall time: 487 ms

# %%
import re
import string

# %%
business_types = [
    'industries',
    'trading',
    'logistics',
    'products',
    'sports',
    'chemicals',
    'polymers',
    'technology',
    'textile',
    'plastic',
    'trade',
    'services',
    'plastics',
    'comercio',
    'technologies',
    'engineering',
    'industria',
    'bank',
    'shipping',
    'freight',
    'materials',
    'electronics',
    'distribution',
    'marketing',
    'supply',
    'transport',
    'traders',
    'logistica',
    'forwarding',
    'equipment',
    'sport',
    'textiles',
    'synthetic',
    'comercial',
    'polymer',
    'service',
    'medical',
    'commercial',
    'electronic',
]

organization_types = [
    'international',
    'enterprises',
    'industrial',
    'group',
    'global',
    'enterprise',
    'industry',
    'worldwide',
    'corporation',
    'overseas',
]

# %%
transliteration = dict([
    (a, a) for a in string.ascii_lowercase + ' '
] + [
    (a, '') for a in string.digits 
] + [
    (a, ' ') for a in string.punctuation
])

transliteration.update({
    'а': 'a',
    'б': 'b',
    'в': 'v',
    'г': 'g',
    'д': 'd',
    'е': 'e',
    'ё': 'yo',
    'ж': 'zh',
    'з': 'z',
    'и': 'i',
    'й': 'i',
    'к': 'k',
    'л': 'l',
    'м': 'm',
    'н': 'n',
    'о': 'o',
    'п': 'p',
    'р': 'r',
    'с': 's',
    'т': 't',
    'у': 'u',
    'ф': 'f',
    'х': 'h',
    'ц': 'ts',
    'ч': 'ch',
    'ш': 'sh',
    'щ': 'sch',
    'ъ': '',
    'ы': 'y',
    'ь': '',
    'э': 'e',
    'ю': 'yu',
    'я': 'ya',
    'ü': 'u',
    'ş': 'sh',
    'ö': 'oe',
    '\xa0': ' ',
    'á': 'a',
    'ç': 'ch',
    'é': 'e',
    'ł': 'w',
    'ó': 'o',
    'ú': 'y',
    'ñ': 'n',
    'í': 'i',
    '\u3000': ' ',
    '\u0e00': ' ',
    'å': 'a',
    'ű': 'u',
    'ő': 'o',
    'ę': 'e',
    'õ': 'o',
    'è': 'e',
    'ã': 'a',
})

def transliterate(s, transliteration=transliteration):
    return ''.join([transliteration.get(c, c) for c in s])

strip_non_alphanum = re.compile(r'\W+', re.UNICODE)
whitespace_normalization = re.compile(r'\s+', re.UNICODE)
abbreviation_glue = re.compile(r'(?<=(?<!\w)\w) (?=\w(?!\w))', re.UNICODE) 
inside_brackets = re.compile(r"\s*\(.*?\)")
def normalize(s):
    s = inside_brackets.sub(' ', s)
    s = strip_non_alphanum.sub(' ', s)
    s = whitespace_normalization.sub(' ', s)
    s = abbreviation_glue.sub('', s)
    s = transliterate(s)
    
    return s.strip()

def multi_str_replace(strings, debug=True, borders=True):
    re_str = '|'.join(
        [re.escape(s) for s in strings]
    )
    if borders:
        re_str = r'\b(?:' + re_str + r')(?!\S)'
        
    if debug:
        print(re_str)
    return re.compile(re_str, re.UNICODE)

legal_entities = [
    "ltd", "co", "inc", "bv", "scrl", 
    "gmbh", "pvt", "private", "limited", "incorporated", 
    "company", "sa", "ltda", "llc", "corp",
]

# %%
import pycountry

legal_re = multi_str_replace(legal_entities)
countries = [normalize(country.name.lower()) for country in pycountry.countries]
countries_re = multi_str_replace(countries)
org_re = multi_str_replace(organization_types)
business_re = multi_str_replace(business_types)
# Out:
# \b(?:ltd|co|inc|bv|scrl|gmbh|pvt|private|limited|incorporated|company|sa|ltda|llc|corp)(?!\S)
# \b(?:aruba|afghanistan|angola|anguilla|aland\ islands|albania|andorra|united\ arab\ emirates|argentina|armenia|american\ samoa|antarctica|french\ southern\ territories|antigua\ and\ barbuda|australia|austria|azerbaijan|burundi|belgium|benin|bonaire\ sint\ eustatius\ and\ saba|burkina\ faso|bangladesh|bulgaria|bahrain|bahamas|bosnia\ and\ herzegovina|saint\ barthelemy|belarus|belize|bermuda|bolivia\ plurinational\ state\ of|brazil|barbados|brunei\ darussalam|bhutan|bouvet\ island|botswana|central\ african\ republic|canada|cocos\ islands|switzerland|chile|china|c\ôte\ d\ ivoire|cameroon|congo\ the\ democratic\ republic\ of\ the|congo|cook\ islands|colombia|comoros|cabo\ verde|costa\ rica|cuba|curachao|christmas\ island|cayman\ islands|cyprus|czechia|germany|djibouti|dominica|denmark|dominican\ republic|algeria|ecuador|egypt|eritrea|western\ sahara|spain|estonia|ethiopia|finland|fiji|falkland\ islands|france|faroe\ islands|micronesia\ federated\ states\ of|gabon|united\ kingdom|georgia|guernsey|ghana|gibraltar|guinea|guadeloupe|gambia|guinea\ bissau|equatorial\ guinea|greece|grenada|greenland|guatemala|french\ guiana|guam|guyana|hong\ kong|heard\ island\ and\ mcdonald\ islands|honduras|croatia|haiti|hungary|indonesia|isle\ of\ man|india|british\ indian\ ocean\ territory|ireland|iran\ islamic\ republic\ of|iraq|iceland|israel|italy|jamaica|jersey|jordan|japan|kazakhstan|kenya|kyrgyzstan|cambodia|kiribati|saint\ kitts\ and\ nevis|korea\ republic\ of|kuwait|lao\ people\ s\ democratic\ republic|lebanon|liberia|libya|saint\ lucia|liechtenstein|sri\ lanka|lesotho|lithuania|luxembourg|latvia|macao|saint\ martin|morocco|monaco|moldova\ republic\ of|madagascar|maldives|mexico|marshall\ islands|north\ macedonia|mali|malta|myanmar|montenegro|mongolia|northern\ mariana\ islands|mozambique|mauritania|montserrat|martinique|mauritius|malawi|malaysia|mayotte|namibia|new\ caledonia|niger|norfolk\ island|nigeria|nicaragua|niue|netherlands|norway|nepal|nauru|new\ zealand|oman|pakistan|panama|pitcairn|peru|philippines|palau|papua\ new\ guinea|poland|puerto\ rico|korea\ democratic\ people\ s\ republic\ of|portugal|paraguay|palestine\ state\ of|french\ polynesia|qatar|reunion|romania|russian\ federation|rwanda|saudi\ arabia|sudan|senegal|singapore|south\ georgia\ and\ the\ south\ sandwich\ islands|saint\ helena\ ascension\ and\ tristan\ da\ cunha|svalbard\ and\ jan\ mayen|solomon\ islands|sierra\ leone|el\ salvador|san\ marino|somalia|saint\ pierre\ and\ miquelon|serbia|south\ sudan|sao\ tome\ and\ principe|suriname|slovakia|slovenia|sweden|eswatini|sint\ maarten|seychelles|syrian\ arab\ republic|turks\ and\ caicos\ islands|chad|togo|thailand|tajikistan|tokelau|turkmenistan|timor\ leste|tonga|trinidad\ and\ tobago|tunisia|turkey|tuvalu|taiwan\ province\ of\ china|tanzania\ united\ republic\ of|uganda|ukraine|united\ states\ minor\ outlying\ islands|uruguay|united\ states|uzbekistan|holy\ see|saint\ vincent\ and\ the\ grenadines|venezuela\ bolivarian\ republic\ of|virgin\ islands\ british|virgin\ islands\ us|viet\ nam|vanuatu|wallis\ and\ futuna|samoa|yemen|south\ africa|zambia|zimbabwe)(?!\S)
# \b(?:international|enterprises|industrial|group|global|enterprise|industry|worldwide|corporation|overseas)(?!\S)
# \b(?:industries|trading|logistics|products|sports|chemicals|polymers|technology|textile|plastic|trade|services|plastics|comercio|technologies|engineering|industria|bank|shipping|freight|materials|electronics|distribution|marketing|supply|transport|traders|logistica|forwarding|equipment|sport|textiles|synthetic|comercial|polymer|service|medical|commercial|electronic)(?!\S)

# %%
# %%time

for dataset in (train, test):
    dataset[['name_1_n', 'name_2_n']] = dataset[['name_1', 'name_2']].apply(np.vectorize(normalize))
# Out:
# CPU times: user 12.5 s, sys: 599 ms, total: 13.1 s
# Wall time: 13.1 s

# %%
def get_tokens(s):
    return s.split(' ')


def word_intersection(values):
    a, b = values
    a, b = [get_tokens(s) for s in (a, b)]
    
    return ' '.join([w for w in a if w in set(a).intersection(b)])


def word_difference(values):
    a, b = values
    a, b = [get_tokens(s) for s in (a, b)]
    
    return ' '.join([w for w in a + b if w in set(a).symmetric_difference(b)])

# %%
# %%time

for dataset in (train, test):
    dataset['intersection'] = dataset[['name_1_n', 'name_2_n']].apply(word_intersection, axis=1)
    dataset['word_difference'] = dataset[['name_1_n', 'name_2_n']].apply(word_difference, axis=1)
# Out:
# CPU times: user 17.1 s, sys: 364 ms, total: 17.4 s
# Wall time: 17.5 s

# %%
# %%time

for dataset in (train, test):
    texts = dataset[['intersection', 'word_difference']]
    texts = texts.replace(legal_re, "LEGAL", inplace=False)
    texts = texts.replace(countries_re, "COUNTRY", inplace=False)
    texts = texts.replace(org_re, "ORG", inplace=False)
    dataset[['intersection', 'word_difference']] = texts
# Out:
# CPU times: user 11.7 s, sys: 93.2 ms, total: 11.8 s
# Wall time: 11.8 s

# %%
from tqdm.notebook import tqdm

pd.concat([
    train.sample(10),
    train[train.is_duplicate == 1].sample(10),
], axis=0, ignore_index=True)[['is_duplicate', 'name_1_n', 'name_2_n', 'intersection', 'word_difference']]
# Out:
#     is_duplicate                                          name_1_n  \
# 0              0                        quimiplast ingenieria ltda
# 1              0                   kerry logistics mexico sa de cv
# 2              0                    briggs industrial footwear ltd
# 3              0  trelleborg industrial products india private ltd
# 4              0                    nakagawa kaname trading co ltd
# 5              0                    extreme importers services ltd
# 6              0                                cbc trading co ltd
# 7              0        shenzhen huadingsheng imp exp trade co ltd
# 8              0                            mathiesen colombia sas
# 9              0                                           nri inc
# 10             1                                        eni jr inc
# 11             1                         yokohama tire mfg virgini
# 12             1                                  bridgestone tire
# 13             1                                     ineos usa llc
# 14             1  bridgestone do brasil industria e comenrcio ltda
# 15             1                                   bridgestone ncr
# 16             1                                  dow europe gmb h
# 17             1                                  zeon corporation
# 18             1                   bridgestone international group
# 19             1                   bridgestone firestone do brasil
#
#                                             name_2_n         intersection  \
# 0                           mir international co ltd
# 1                                   bmc logistic sas
# 2                                            mti llc
# 3                                                dsa
# 4                                      ag trading co        trading LEGAL
# 5                                        trex co inc
# 6                          ralhum trading co pvt ltd  trading LEGAL LEGAL
# 7                                    mmr imp exp llp              imp exp
# 8                          quad graphics colombia sa              COUNTRY
# 9                      steve madden south africa ltd
# 10                          eni shipping inc houston            eni LEGAL
# 11                            yokohama india pvt ltd             yokohama
# 12  bridgestone do brasil industria e comenrcio ltda          bridgestone
# 13        ineos styrolution do brasil polimeros ltda                ineos
# 14                      bridgestone de costa rica sa          bridgestone
# 15                                 bridgestone india          bridgestone
# 16                          dow europe gmb h plant f     dow europe gmb h
# 17                      zeon specialty materials inc                 zeon
# 18                       bridgestone stargard sp zoo          bridgestone
# 19       bridgestone research and development co ltd          bridgestone
#
#                                       word_difference
# 0     quimiplast ingenieria LEGAL mir ORG LEGAL LEGAL
# 1   kerry logistics COUNTRY LEGAL de cv bmc logist...
# 2                 briggs ORG footwear LEGAL mti LEGAL
# 3     trelleborg ORG products COUNTRY LEGAL LEGAL dsa
# 4                            nakagawa kaname LEGAL ag
# 5   extreme importers services LEGAL trex LEGAL LEGAL
# 6                                    cbc ralhum LEGAL
# 7     shenzhen huadingsheng trade LEGAL LEGAL mmr llp
# 8                   mathiesen sas quad graphics LEGAL
# 9                nri LEGAL steve madden COUNTRY LEGAL
# 10                                jr shipping houston
# 11               tire mfg virgini COUNTRY LEGAL LEGAL
# 12         tire do brasil industria e comenrcio LEGAL
# 13    usa LEGAL styrolution do brasil polimeros LEGAL
# 14  do brasil industria e comenrcio LEGAL de COUNT...
# 15                                        ncr COUNTRY
# 16                                            plant f
# 17                      ORG specialty materials LEGAL
# 18                            ORG ORG stargard sp zoo
# 19  firestone do brasil research and development L...

# %%
from sklearn.svm import LinearSVC
from sklearn.feature_extraction.text import CountVectorizer
from scipy import sparse 

model = LinearSVC(C=1)

# Using only train because of rules limitation to exploit test part
vectorizer = CountVectorizer(lowercase=False, ngram_range=(1, 1))
vectorizer.fit(train['intersection'] + ' ' + train['word_difference'])


def build_features(dataset):
    X = sparse.hstack([
        vectorizer.transform(dataset['intersection']),
        vectorizer.transform(dataset['word_difference']),
    ])
    return X


def build_features_same_space(dataset):
    X = (
        vectorizer.transform(dataset['intersection'])
        - vectorizer.transform(dataset['word_difference'])
    )
    
    return X

# %%
# %%time

X_train, X_test = [
    build_features_same_space(dataset)
    for dataset in (train, test)
]
# Out:
# CPU times: user 6.19 s, sys: 72.8 ms, total: 6.26 s
# Wall time: 6.27 s

# %%
X_train.shape, X_test.shape
# Out:
# ((497819, 15968), (213249, 15968))

# %%
y_train = train['is_duplicate'].values
model.fit(X_train, y_train)
# Out:
# LinearSVC(C=1)

# %%
p_train = model.decision_function(X_train)

# %%
train['p'] = p_train
threshold = 0.95 * train.is_duplicate.mean()
train[(train['p'].rank(pct=True) >=  (1 - threshold)) & (train['is_duplicate'] == 0)]
# Out:
#                                            name_1  \
# pair_id
# 104190                           yokohama re mfg.
# 264480    total oil india private limited,  total
# 345098                              yokohama tyre
#
#                                 name_2  is_duplicate  \
# pair_id
# 104190   the yokohama rubber co., ltd.             0
# 264480         total polska sp. z o.o.             0
# 345098   the yokohama rubber co., ltd.             0
#
#                                       name_1_n                    name_2_n  \
# pair_id
# 104190                         yokohama re mfg  the yokohama rubber co ltd
# 264480   total oil india private limited total         total polska sp zoo
# 345098                           yokohama tyre  the yokohama rubber co ltd
#
#         intersection                        word_difference         p
# pair_id
# 104190      yokohama          re mfg the rubber LEGAL LEGAL  0.761664
# 264480   total total  oil COUNTRY LEGAL LEGAL polska sp zoo  0.821822
# 345098      yokohama            tyre the rubber LEGAL LEGAL  0.851947

# %%
p_test = model.decision_function(X_test)

# %%
sample_sub = pd.read_csv(
    DATA_DIR.joinpath("sample_submission.csv"), 
    index_col="pair_id"
)

# %%
rank_threshold = 0.9 * train['is_duplicate'].mean()

test['is_duplicate'] = p_test
test['is_duplicate'] = test['is_duplicate'].rank(pct=True)

test['is_duplicate'] = (test.is_duplicate >= 1 - rank_threshold).astype(int)

# %%
test['p'] = p_test

# %%
test[test['is_duplicate'] == 1].sample(5)
# Out:
#                                                     name_1  \
# pair_id
# 186272                         sojitz (thailand) co., ltd.
# 111762   shaoguang debao electronic science & technolog...
# 139255                          rpi de mexicos de rl de cv
# 103299                          ооо"пауль хартманн сибирь"
# 154011   общество с ограниченной ответственностью asia ...
#
#                                                    name_2  \
# pair_id
# 186272                                  sojitz (shanghai)
# 111762   shaoguang kangrui science & technology co., ltd.
# 139255                           cuno mexicos de rl de cv
# 103299                         ооо"пауль хартманн сибирь"
# 154011                                             мишлен
#
#                                                   name_1_n  \
# pair_id
# 186272                                       sojitz co ltd
# 111762   shaoguang debao electronic science technology ...
# 139255                          rpi de mexicos de rl de cv
# 103299                             ooo paul hartmann sibir
# 154011   obschestvo s ogranichennoi otvetstvennostyu as...
#
#                                             name_2_n  \
# pair_id
# 186272                                        sojitz
# 111762   shaoguang kangrui science technology co ltd
# 139255                      cuno mexicos de rl de cv
# 103299                       ooo paul hartmann sibir
# 154011                                       mishlen
#
#                                      intersection  \
# pair_id
# 186272                                     sojitz
# 111762   shaoguang science technology LEGAL LEGAL
# 139255                     de mexicos de rl de cv
# 103299                    ooo paul hartmann sibir
# 154011
#
#                                            word_difference  is_duplicate  \
# pair_id
# 186272                                         LEGAL LEGAL             1
# 111762                            debao electronic kangrui             1
# 139255                                            rpi cuno             1
# 103299                                                                 1
# 154011   obschestvo s ogranichennoi otvetstvennostyu as...             1
#
#                 p
# pair_id
# 186272  -0.713619
# 111762  -0.470339
# 139255  -0.851562
# 103299  -0.772879
# 154011  -0.819801

# %%
test[test['is_duplicate'] == 0].sample(5)
# Out:
#                                                     name_1  \
# pair_id
# 138067   c.o.i.m. s.p.a. chimica organica industriale m...
# 108075                                 daksma s.a. de c.v.
# 94578                    joe fu qingyuan plastic co., ltd.
# 150078                                     rankin usa inc.
# 102499       mafer ind e com de artefatos de borracha ltda
#
#                             name_2  \
# pair_id
# 138067             parker kawakami
# 108075         danosa caribbean in
# 94578    asimco international inc.
# 150078           adk international
# 102499                     coachap
#
#                                               name_1_n  \
# pair_id
# 138067   coimspa chimica organica industriale milanese
# 108075                                 daksma sa de cv
# 94578                   joe fu qingyuan plastic co ltd
# 150078                                  rankin usa inc
# 102499   mafer ind e com de artefatos de borracha ltda
#
#                          name_2_n intersection  \
# pair_id
# 138067            parker kawakami
# 108075        danosa caribbean in
# 94578    asimco international inc
# 150078          adk international
# 102499                    coachap
#
#                                            word_difference  is_duplicate  \
# pair_id
# 138067   coimspa chimica organica industriale milanese ...             0
# 108075              daksma LEGAL de cv danosa caribbean in             0
# 94578    joe fu qingyuan plastic LEGAL LEGAL asimco ORG...             0
# 150078                            rankin usa LEGAL adk ORG             0
# 102499   mafer ind e com de artefatos de borracha LEGAL...             0
#
#                 p
# pair_id
# 138067  -2.305935
# 108075  -2.965076
# 94578   -1.306770
# 150078  -1.107713
# 102499  -1.728003

# %%
test_result = test[['is_duplicate', 'p']]

# %%
del sample_sub['is_duplicate']

# %%
sample_sub = sample_sub.merge(test_result, left_index=True, right_index=True, how='left')

# %%
sample_sub.is_duplicate.mean()
# Out:
# 0.0066166781555833795

# %%
train.is_duplicate.mean()
# Out:
# 0.007348052203712594

# %%
RESULT_DIR = pathlib.Path("submissions")

# %%
sample_sub[['is_duplicate']].to_csv(
    RESULT_DIR.joinpath(f"model_{SUBMISSION_N}_submission.csv.gz"), 
    compression='infer'
)

# %%
sample_sub[['p']].to_csv(
    RESULT_DIR.joinpath(f"model_{SUBMISSION_N}_submission_raw.csv.gz"), 
    compression='infer'
)

# %%
reverse = [word for _, word in sorted([(v, k) for k, v in vectorizer.vocabulary_.items()])]

# %%
from itertools import chain
from collections import Counter

characters = Counter(chain(*train['name_1_n'].values, *train['name_2_n'].values)).most_common()

# %%
sorted(
    zip(list(model.coef_[0]), [f'i_{w}' for w in reverse] + [f'd_{w}' for w in reverse]), 
    key=lambda x: -abs(x[0])
)[:300]
# Out:
# [(2.822308879731156, 'i_api'),
#  (-2.4835919392440657, 'i_zs'),
#  (-2.4495503735543855, 'i_aiko'),
#  (2.3641088958290997, 'i_lotte'),
#  (2.304404333088943, 'i_fenner'),
#  (2.128929013914652, 'i_bridgestone'),
#  (2.091339389039545, 'i_polimarket'),
#  (-2.0840006588401154, 'i_zika'),
#  (2.056409748681573, 'i_wuxi'),
#  (2.0236123410189375, 'i_basf'),
#  (2.0234802507628444, 'i_artsana'),
#  (2.0234802069031135, 'i_guchchi'),
#  (1.9637436946180602, 'i_brenntag'),
#  (1.9591944805338197, 'i_soprema'),
#  (1.9570739732137001, 'i_reliance'),
#  (1.9569161265962465, 'i_giti'),
#  (1.9554553383696118, 'i_exxonmobil'),
#  (1.9522067976545725, 'i_contitech'),
#  (1.9492524715065533, 'i_ravago'),
#  (1.9344833697297166, 'i_daewoo'),
#  (1.9279201713286938, 'i_pirelli'),
#  (1.923991305092052, 'i_zeon'),
#  (1.9170553326237114, 'i_sika'),
#  (1.9150115000099555, 'i_arlanxeo'),
#  (-1.8890711835856755, 'i_poliglas'),
#  (1.8879713404335465, 'i_synthomer'),
#  (1.8721299793895938, 'i_ineos'),
#  (1.8709025535187613, 'i_kenda'),
#  (1.8634532992244635, 'i_toyo'),
#  (1.8572229596430485, 'i_bharat'),
#  (1.8383334945329812, 'i_evonik'),
#  (1.837420718310647, 'i_petro'),
#  (1.8319970486332156, 'i_sumitomo'),
#  (1.7941099186188856, 'i_marathon'),
#  (1.7928142186120348, 'i_kraton'),
#  (1.7639437109853287, 'i_iko'),
#  (1.76318970420819, 'i_yokohama'),
#  (1.7576597226585766, 'i_michelin'),
#  (1.738765233733596, 'i_kuraray'),
#  (1.7291841719273715, 'i_versalis'),
#  (1.7224646223581765, 'i_crosspolimeri'),
#  (1.7096932275674865, 'i_hexpol'),
#  (1.6999619235748777, 'i_dow'),
#  (-1.6997682956502136, 'i_fleks'),
#  (1.6833135659450145, 'i_maxwell'),
#  (-1.6683190880679024, 'i_slazenger'),
#  (1.6494334865448548, 'i_synthos'),
#  (1.6481287623863552, 'i_sumika'),
#  (1.6456775655142768, 'i_afton'),
#  (1.6433618552093208, 'i_sunflag'),
#  (1.6344953829914446, 'i_flex'),
#  (1.6325135892235545, 'i_eni'),
#  (1.629746809546835, 'i_adi'),
#  (1.626597416388871, 'i_rusplast'),
#  (1.6265973356542034, 'i_huskvarna'),
#  (1.6265973225253252, 'i_olimp'),
#  (1.6265973187791927, 'i_ortgraf'),
#  (1.6265973104967686, 'i_impeks'),
#  (1.6265973102165892, 'i_manders'),
#  (1.6265972947038527, 'i_himmarket'),
#  (1.6265972854629467, 'i_mediainvest'),
#  (1.6265972672188667, 'i_kamimp'),
#  (1.6265972621642502, 'i_starkom'),
#  (1.6232611574647944, 'i_makyol'),
#  (1.6218758793384427, 'i_eurovia'),
#  (1.6142466108359796, 'i_ashland'),
#  (1.6037286675634688, 'i_trinseo'),
#  (1.5900148739565494, 'i_plastay'),
#  (1.5899253955602548, 'i_exploration'),
#  (1.5877529019865677, 'i_albemarle'),
#  (1.5782952640516643, 'i_vertikal'),
#  (1.5437061878780998, 'i_soudal'),
#  (1.5317956499756007, 'i_danisco'),
#  (1.5317956139724354, 'i_aplix'),
#  (1.5317956045383678, 'i_clopay'),
#  (1.5300508806964153, 'i_braas'),
#  (1.5300505657260537, 'i_malarkey'),
#  (1.5300505052247244, 'i_technonikol'),
#  (1.5283055503712935, 'i_kvk'),
#  (1.5283055503550944, 'i_vedag'),
#  (1.528305534327742, 'i_bitumtec'),
#  (1.5254198693188923, 'i_goter'),
#  (1.5233106140088175, 'i_exel'),
#  (1.5218278830800087, 'i_lcy'),
#  (1.5117965702292486, 'i_prometeon'),
#  (1.505719638972156, 'i_kildair'),
#  (1.5047439641024378, 'i_pigipada'),
#  (1.5022081981913815, 'i_achem'),
#  (1.4992133876737714, 'i_gymap'),
#  (1.4835926772444024, 'i_youngnam'),
#  (1.4652110964245768, 'i_dynasol'),
#  (-1.4630930001784082, 'i_softer'),
#  (1.4521493681195716, 'i_joss'),
#  (-1.4512977313786246, 'i_bisterfeld'),
#  (1.443205638754175, 'i_hv'),
#  (1.4408502996531487, 'i_aps'),
#  (1.4188512610018316, 'i_lagan'),
#  (1.4123967850986103, 'i_shangdong'),
#  (1.4039041073161795, 'i_spc'),
#  (1.3983149656006921, 'i_showa'),
#  (1.395947200877162, 'i_omv'),
#  (1.3942263141528883, 'i_treid'),
#  (1.3864377676341417, 'i_indian'),
#  (1.3858536592276143, 'i_probisa'),
#  (-1.3723726524345865, 'i_hungaria'),
#  (-1.3723726524345865, 'i_manufacture'),
#  (1.3718870958836964, 'i_cabopol'),
#  (1.368816141366315, 'i_eiffage'),
#  (1.3686969415595884, 'i_recron'),
#  (-1.3624499479518275, 'i_kompogal'),
#  (-1.3607812388420404, 'i_kgaa'),
#  (-1.3607812388420404, 'i_reifenwerke'),
#  (1.3607083865504817, 'i_binne'),
#  (1.3542850256356456, 'i_celanese'),
#  (1.336825367584926, 'i_rhino'),
#  (1.3313686293975644, 'i_cobalt'),
#  (1.3269382977663446, 'i_hangzhou'),
#  (1.311329713140284, 'i_adriatica'),
#  (1.3088995248598938, 'i_fragmat'),
#  (1.298763675749797, 'i_georg'),
#  (1.2987331469768417, 'i_termocompo'),
#  (1.2936203196708966, 'i_hira'),
#  (1.2935535767762985, 'i_dunlop'),
#  (1.2933259563301724, 'i_petrotekno'),
#  (1.2902658288671562, 'i_cengiz'),
#  (1.2897748252247088, 'i_leman'),
#  (1.2885561611169778, 'i_helm'),
#  (1.2838191844580977, 'i_rogitex'),
#  (1.2809539126201839, 'i_fourny'),
#  (1.2809109079135361, 'i_cts'),
#  (1.2792061264965362, 'i_danosa'),
#  (1.2773380858025802, 'i_famos'),
#  (1.2764963340085076, 'i_blufixx'),
#  (1.2764963190697023, 'i_wakol'),
#  (1.2764963088050412, 'i_ditecpesa'),
#  (1.2764962987504236, 'i_crafco'),
#  (1.2764962692852249, 'i_aspa'),
#  (1.2764962554320671, 'i_multibase'),
#  (1.2764962535429294, 'i_bitumix'),
#  (1.2713302968683133, 'i_garland'),
#  (1.270679579108823, 'i_bitoumina'),
#  (1.270679556931355, 'i_eterna'),
#  (1.2676616050615415, 'i_cardinal'),
#  (1.266680897009789, 'i_comlink'),
#  (1.2653903397104842, 'i_negromex'),
#  (1.2640210452992229, 'i_lohmann'),
#  (1.258668223307509, 'i_swisspor'),
#  (1.254646658701328, 'i_vaparoid'),
#  (1.2546466243309955, 'i_grisard'),
#  (1.2546466162804117, 'i_porr'),
#  (1.253131720525744, 'i_dupont'),
#  (1.2510475825187488, 'i_assa'),
#  (1.249909743786742, 'i_ply'),
#  (1.2419093045690999, 'i_bauder'),
#  (1.2405897698696582, 'i_membrane'),
#  (1.221546487635034, 'i_total'),
#  (1.2163553842551438, 'i_league'),
#  (1.2136030273728369, 'i_auriquimica'),
#  (1.2047134957123755, 'i_varo'),
#  (1.203649191482059, 'i_suzhou'),
#  (1.2003723378456996, 'i_izobud'),
#  (1.1890385777922987, 'i_medi'),
#  (1.167900647455816, 'i_sanyhot'),
#  (1.1608547487418706, 'i_izolirka'),
#  (1.1594470063072444, 'i_oil'),
#  (1.1475228382558056, 'i_him'),
#  (-1.14216832308529, 'i_tradig'),
#  (1.13696586962344, 'i_moda'),
#  (1.1339639369237056, 'i_icopal'),
#  (1.128385782542717, 'i_inreco'),
#  (-1.1216383623603752, 'i_sands'),
#  (1.117503255484115, 'i_fayette'),
#  (1.111507238609177, 'i_assets'),
#  (1.1030745794417558, 'i_dragon'),
#  (1.102035762897825, 'i_dukt'),
#  (1.1020357617475296, 'i_emulbit'),
#  (1.09658004832032, 'i_dalpo'),
#  (1.0946197136901394, 'i_wright'),
#  (1.0921363334953864, 'i_panda'),
#  (1.0900343927756269, 'i_kawakami'),
#  (1.0880113735039083, 'i_bochem'),
#  (1.0865138874739773, 'i_adams'),
#  (1.0837711292034762, 'i_hikari'),
#  (-1.08321122892098, 'i_zao'),
#  (1.0796654189399584, 'i_beton'),
#  (-1.074372619286906, 'i_iovat'),
#  (1.072441727439099, 'i_ankara'),
#  (-1.067604954273103, 'i_ondulin'),
#  (1.064799003032826, 'i_keramika'),
#  (1.0601145862832373, 'i_sabic'),
#  (1.0326778286802938, 'i_colquimica'),
#  (1.0216684320131448, 'i_refining'),
#  (1.015159897793733, 'i_baoli'),
#  (1.0091799214448476, 'i_pafra'),
#  (1.0062714973061326, 'i_bolton'),
#  (0.9989588179669626, 'i_anser'),
#  (0.9967333511827347, 'i_mogat'),
#  (0.9958804912406487, 'i_quandt'),
#  (-0.9953263843365968, 'i_kopernit'),
#  (0.991869769351844, 'i_epson'),
#  (0.9886148306639684, 'i_stemaco'),
#  (0.9884457114203027, 'i_bitumenka'),
#  (0.986777077124068, 'i_rehau'),
#  (0.9799700751828149, 'i_bitbau'),
#  (0.9780643646930995, 'i_phillips'),
#  (0.9770659837478001, 'i_gelaksi'),
#  (0.9770659837478001, 'i_kargo'),
#  (0.9759584360427513, 'i_dom'),
#  (0.9759584360427513, 'i_odezhdy'),
#  (0.9759584192420281, 'i_mir'),
#  (0.975958419242028, 'i_novyi'),
#  (0.9759584162213734, 'i_ekspress'),
#  (0.9759584162213734, 'i_kyu'),
#  (0.9759583872894982, 'i_favorit'),
#  (0.9759583872894982, 'i_stail'),
#  (0.9759583806266415, 'i_oborudovanie'),
#  (0.9759583806266415, 'i_spetsialnoe'),
#  (0.975958360537412, 'i_grupp'),
#  (0.975958360537412, 'i_himinvest'),
#  (0.9747328921028566, 'i_cardiac'),
#  (-0.9735663672132234, 'i_plants'),
#  (0.9719208899509113, 'i_avebe'),
#  (0.9620503175189596, 'i_taban'),
#  (0.9619150983836302, 'i_biesterfeld'),
#  (0.9616965884067127, 'i_mct'),
#  (0.9610464805542507, 'i_sherwin'),
#  (0.9587952616842992, 'i_duracell'),
#  (0.9555342538801276, 'i_corning'),
#  (0.9555342538801271, 'i_owens'),
#  (0.9541888042155615, 'i_puma'),
#  (0.9525316539172279, 'i_tuba'),
#  (0.951741451367274, 'i_mitas'),
#  (0.9463181816432814, 'i_abena'),
#  (0.9419967547490633, 'i_zairyo'),
#  (0.9392905181797961, 'i_zhechen'),
#  (0.9359621573985969, 'i_isolago'),
#  (0.9348199209177392, 'i_teamwear'),
#  (0.9342579152929944, 'i_specialties'),
#  (0.9339993367029535, 'i_kumho'),
#  (0.9283629026494837, 'i_hengbin'),
#  (-0.9277515003528324, 'i_denisson'),
#  (0.9244588587864414, 'i_eastland'),
#  (0.9235868361289499, 'i_goldenplast'),
#  (0.9234868719336699, 'i_peri'),
#  (-0.9194641240050054, 'i_nekst'),
#  (0.9188013858956982, 'i_farmacap'),
#  (0.9181738488718669, 'i_demo'),
#  (0.9180245675223205, 'i_polyglass'),
#  (0.9172370080035478, 'i_pbm'),
#  (0.9149148805445149, 'i_probigalp'),
#  (-0.9132679113222699, 'i_byuler'),
#  (0.9089277694318036, 'i_superbeton'),
#  (0.9016372829321702, 'i_krones'),
#  (0.9006357296293998, 'i_goodyear'),
#  (0.8993381956142379, 'i_kleiberit'),
#  (-0.8992468434430901, 'i_emulsje'),
#  (0.8949010639776822, 'i_tokyo'),
#  (0.8938650250418012, 'i_dana'),
#  (0.8875995311796568, 'i_denka'),
#  (0.8875341312742939, 'i_ikea'),
#  (0.8807033814603769, 'i_lusocopla'),
#  (0.8796592331738514, 'i_vetroasfalto'),
#  (0.879301033068493, 'i_rollers'),
#  (0.8786621607319351, 'i_casali'),
#  (0.8759930859727837, 'i_tecnofilm'),
#  (0.8717888649402377, 'i_heartychem'),
#  (0.8705096538210507, 'i_bitufa'),
#  (-0.8698494183510552, 'i_vostok'),
#  (0.8690939596444603, 'i_esha'),
#  (0.8632270713348824, 'i_akrotex'),
#  (0.8630474822491127, 'i_toa'),
#  (-0.859482669272042, 'i_goergia'),
#  (0.8590233433248698, 'i_vestas'),
#  (-0.8558794683680684, 'i_hevea'),
#  (-0.8558794683680684, 'i_heveachem'),
#  (0.852334477266708, 'i_rompetrol'),
#  (0.8518337302768432, 'i_lotos'),
#  (0.8513052271265122, 'i_onur'),
#  (0.8513052271265122, 'i_taahhut'),
#  (0.8513009798659884, 'i_loi'),
#  (0.8513009798659884, 'i_thuan'),
#  (0.8489128943786123, 'i_pavimental'),
#  (0.8477527362333452, 'i_chova'),
#  (0.8462041221657522, 'i_egorevsk'),
#  (0.8462041221657522, 'i_obuv'),
#  (0.8448444199705192, 'i_emam'),
#  (0.8426974600098294, 'i_el'),
#  (0.8411446491473892, 'i_coin'),
#  (0.8404826130485556, 'i_servicom'),
#  (-0.8379618566186124, 'i_gongguan'),
#  (0.8320341908664537, 'i_alfagomma'),
#  (0.8243017005942391, 'i_lion'),
#  (0.8234419390249808, 'i_kaluga'),
#  (0.8229607421019681, 'i_univar'),
#  (0.8221532406643187, 'i_ekson'),
#  (0.8221532406643187, 'i_neftegaz'),
#  (0.8175492377315791, 'i_marangoni'),
#  (0.8175492377315791, 'i_retreading'),
#  (-0.8161329406088642, 'i_dzhons'),
#  (-0.8161329406088642, 'i_mansvil')]

# %%
[c for c in characters if c[0].lower() not in transliteration ]
# Out:
# [('双', 130),
#  ('日', 130),
#  ('株', 130),
#  ('式', 130),
#  ('会', 130),
#  ('社', 130),
#  ('س', 121),
#  ('ر', 121),
#  ('ف', 121),
#  ('ي', 121),
#  ('ك', 121),
#  ('و', 121),
#  ('م', 121),
#  ('上', 96),
#  ('海', 96),
#  ('北', 1),
#  ('京', 1),
#  ('东', 1),
#  ('方', 1),
#  ('雨', 1),
#  ('虹', 1),
#  ('防', 1),
#  ('水', 1),
#  ('技', 1),
#  ('术', 1),
#  ('股', 1),
#  ('份', 1),
#  ('有', 1),
#  ('限', 1),
#  ('公', 1),
#  ('司', 1)]

# %%
Counter(chain(*dataset['intersection'].apply(get_tokens).values)).most_common(300)
# Out:
# [('', 129841),
#  ('LEGAL', 42473),
#  ('industries', 8875),
#  ('trading', 8871),
#  ('logistics', 8023),
#  ('de', 7000),
#  ('COUNTRY', 6854),
#  ('ORG', 6633),
#  ('rubber', 4527),
#  ('cv', 3004),
#  ('imp', 2892),
#  ('exp', 2850),
#  ('products', 1965),
#  ('sports', 1018),
#  ('chemicals', 865),
#  ('america', 774),
#  ('chemical', 763),
#  ('polymers', 756),
#  ('technology', 624),
#  ('textile', 584),
#  ('shanghai', 578),
#  ('plastic', 456),
#  ('trade', 436),
#  ('services', 430),
#  ('plastics', 427),
#  ('comercio', 395),
#  ('dongguan', 395),
#  ('usa', 365),
#  ('rl', 357),
#  ('technologies', 356),
#  ('s', 351),
#  ('general', 343),
#  ('spinning', 320),
#  ('engineering', 319),
#  ('industria', 315),
#  ('brasil', 291),
#  ('qingdao', 275),
#  ('polychem', 270),
#  ('bank', 260),
#  ('solutions', 258),
#  ('shipping', 257),
#  ('shenzhen', 238),
#  ('freight', 232),
#  ('e', 225),
#  ('sociedad', 200),
#  ('automotive', 199),
#  ('materials', 192),
#  ('anonima', 185),
#  ('the', 180),
#  ('do', 176),
#  ('mills', 175),
#  ('electronics', 165),
#  ('goodyear', 160),
#  ('of', 157),
#  ('express', 149),
#  ('henkel', 145),
#  ('trelleborg', 144),
#  ('and', 137),
#  ('tire', 137),
#  ('to', 137),
#  ('cargo', 131),
#  ('systems', 129),
#  ('order', 126),
#  ('shoes', 125),
#  ('distribution', 122),
#  ('marketing', 119),
#  ('mfg', 119),
#  ('al', 118),
#  ('guangzhou', 110),
#  ('supply', 109),
#  ('north', 107),
#  ('logistica', 103),
#  ('forwarding', 100),
#  ('transport', 96),
#  ('traders', 94),
#  ('h', 92),
#  ('equipment', 91),
#  ('gmb', 90),
#  ('rugby', 83),
#  ('samson', 80),
#  ('sojitz', 77),
#  ('industrias', 76),
#  ('textiles', 73),
#  ('synthetic', 73),
#  ('management', 69),
#  ('sport', 69),
#  ('american', 67),
#  ('chem', 65),
#  ('footwear', 62),
#  ('warehouse', 61),
#  ('comercial', 60),
#  ('pt', 59),
#  ('precision', 58),
#  ('ve', 55),
#  ('auto', 54),
#  ('hankook', 53),
#  ('continental', 52),
#  ('parts', 51),
#  ('mexicana', 51),
#  ('pacific', 51),
#  ('polymer', 51),
#  ('transportes', 50),
#  ('quimica', 49),
#  ('world', 49),
#  ('sas', 47),
#  ('chain', 47),
#  ('lg', 46),
#  ('service', 45),
#  ('medical', 45),
#  ('associates', 44),
#  ('electronic', 42),
#  ('comercializadora', 42),
#  ('sales', 42),
#  ('rubbers', 42),
#  ('commercial', 41),
#  ('united', 41),
#  ('development', 40),
#  ('americas', 40),
#  ('lanka', 39),
#  ('national', 39),
#  ('tyres', 38),
#  ('adhesives', 38),
#  ('furniture', 36),
#  ('goods', 36),
#  ('components', 35),
#  ('construction', 35),
#  ('machinery', 35),
#  ('as', 34),
#  ('elastomers', 34),
#  ('retail', 33),
#  ('kg', 33),
#  ('material', 33),
#  ('hardware', 33),
#  ('shandong', 33),
#  ('city', 33),
#  ('distributors', 31),
#  ('exportacao', 31),
#  ('transportation', 31),
#  ('sons', 31),
#  ('leather', 30),
#  ('universal', 30),
#  ('fashion', 29),
#  ('spa', 28),
#  ('productos', 27),
#  ('internacionais', 27),
#  ('limitada', 26),
#  ('agencies', 26),
#  ('importacao', 26),
#  ('total', 25),
#  ('xiamen', 25),
#  ('distribuidora', 25),
#  ('sanyo', 24),
#  ('new', 24),
#  ('synthetics', 24),
#  ('colas', 24),
#  ('brands', 24),
#  ('y', 22),
#  ('performance', 22),
#  ('building', 22),
#  ('lanxess', 22),
#  ('corporacion', 22),
#  ('saint', 22),
#  ('san', 21),
#  ('sp', 21),
#  ('trans', 21),
#  ('air', 21),
#  ('energy', 20),
#  ('importadora', 20),
#  ('tekstil', 20),
#  ('zone', 20),
#  ('motors', 19),
#  ('quimicos', 19),
#  ('asia', 19),
#  ('sac', 19),
#  ('ningbo', 19),
#  ('sanayi', 19),
#  ('ticaret', 19),
#  ('parker', 19),
#  ('tic', 18),
#  ('grupo', 18),
#  ('product', 18),
#  ('science', 18),
#  ('packaging', 18),
#  ('free', 18),
#  ('europe', 18),
#  ('ooo', 18),
#  ('gobain', 18),
#  ('investment', 18),
#  ('manufacturas', 17),
#  ('tech', 17),
#  ('zhongshan', 17),
#  ('produtos', 17),
#  ('srl', 16),
#  ('specialty', 16),
#  ('sdn', 16),
#  ('container', 16),
#  ('inversiones', 16),
#  ('industriales', 16),
#  ('foods', 16),
#  ('holdings', 16),
#  ('direct', 16),
#  ('asphalt', 16),
#  ('mol', 15),
#  ('zoo', 15),
#  ('m', 15),
#  ('nexen', 14),
#  ('scientific', 14),
#  ('factory', 14),
#  ('hannifin', 14),
#  ('steel', 13),
#  ('advanced', 13),
#  ('latex', 13),
#  ('a', 13),
#  ('accessories', 13),
#  ('premier', 13),
#  ('power', 12),
#  ('center', 11),
#  ('societe', 11),
#  ('est', 11),
#  ('super', 11),
#  ('dhl', 11),
#  ('ocean', 11),
#  ('customer', 11),
#  ('banco', 11),
#  ('sporting', 11),
#  ('tex', 11),
#  ('operations', 11),
#  ('abrasives', 11),
#  ('vietnam', 10),
#  ('motor', 10),
#  ('carbon', 10),
#  ('bhd', 10),
#  ('safety', 10),
#  ('brothers', 10),
#  ('servicios', 10),
#  ('oil', 10),
#  ('supplies', 10),
#  ('zoll', 10),
#  ('mitsubishi', 10),
#  ('ag', 9),
#  ('logistic', 9),
#  ('resources', 9),
#  ('leisure', 9),
#  ('golden', 9),
#  ('capital', 9),
#  ('ansell', 9),
#  ('representaciones', 9),
#  ('line', 9),
#  ('metal', 9),
#  ('electric', 9),
#  ('suzhou', 9),
#  ('processing', 9),
#  ('polska', 9),
#  ('club', 9),
#  ('tecnologia', 9),
#  ('light', 9),
#  ('weaving', 9),
#  ('east', 8),
#  ('link', 8),
#  ('paper', 8),
#  ('us', 8),
#  ('d', 8),
#  ('zhejiang', 8),
#  ('shoe', 8),
#  ('plasticos', 8),
#  ('bitumen', 8),
#  ('gas', 8),
#  ('solution', 8),
#  ('mexicosa', 7),
#  ('mold', 7),
#  ('lines', 7),
#  ('foshan', 7),
#  ('eastern', 7),
#  ('consolidation', 7),
#  ('toys', 7),
#  ('production', 7),
#  ('dong', 7),
#  ('seafood', 7),
#  ('carpet', 7),
#  ('venezuela', 7),
#  ('forest', 7),
#  ('foreign', 7),
#  ('arkema', 7),
#  ('llp', 7),
#  ('store', 7),
#  ('com', 7),
#  ('laminados', 7),
#  ('standard', 7),
#  ('minerals', 7),
#  ('exploration', 7),
#  ('halliburton', 7),
#  ('borracha', 7),
#  ('cotton', 7),
#  ('gates', 7),
#  ('del', 7),
#  ('mohammed', 6),
#  ('generale', 6),
#  ('goodtire', 6),
#  ('yokohama', 6),
#  ('fns', 6)]
